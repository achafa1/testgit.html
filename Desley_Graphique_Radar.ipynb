# %% [markdown]
# <a href="https://colab.research.google.com/github/achafa1/testgit.html/blob/main/Desley_Graphique_Radar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Définir les facteurs à comparer
facteurs = ['Fonctionnalités', 'Réputation de la Marque', 'Prix', 'Marché Cible']

# Définir les marques et leurs scores pour chaque facteur
marques = ['Desley Pluggage', 'Rimowa', 'Away', 'Samsonite']
scores = {
    'Desley Pluggage': [9, 8, 7, 8],  # Exemple de scores (sur 10)
    'Rimowa': [7, 9, 10, 7],
    'Away': [8, 7, 8, 9],
    'Samsonite': [7, 8, 7, 8]
}

# Convertir les scores en tableaux numpy
scores_tableau = np.array([scores[marque] for marque in marques])

# Calculer l'angle pour chaque facteur
angles = np.linspace(0, 2 * np.pi, len(facteurs), endpoint=False).tolist()

# Faire le tracé en forme de radar
scores_tableau = np.concatenate((scores_tableau, scores_tableau[:,[0]]), axis=1)
angles += angles[:1]

# Tracé
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
for i, marque in enumerate(marques):
    ax.plot(angles, scores_tableau[i], label=marque, linewidth=1, linestyle='solid')
ax.fill(angles, np.mean(scores_tableau, axis=0), 'gray', alpha=0.1)

# Ajouter les étiquettes
ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(facteurs)
ax.set_title('Graphique Radar de Comparaison de Desley Pluggage avec ses Concurrents', 'color:blue')

# Ajouter une légende
ax.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# Afficher le tracé
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-dd1304c27471> in <cell line: 36>()
#      34 ax.set_xticks(angles[:-1])
#      35 ax.set_xticklabels(facteurs)
# ---> 36 ax.set_title('Graphique Radar de Comparaison de Desley Pluggage avec ses Concurrents', 'color:blue')
#      37
#      38 # Ajouter une légende
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in set_title(self, label, fontdict, loc, pad, y, **kwargs)
#     177         title.update(default)
#     178         if fontdict is not None:
# --> 179             title.update(fontdict)
#     180         title._internal_update(kwargs)
#     181         return title
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/text.py in update(self, kwargs)
#     221     def update(self, kwargs):
#     222         # docstring inherited
# ...
